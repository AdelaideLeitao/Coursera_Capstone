# %% [markdown]
# # IBM Data Science Professional Certificate @Coursera
# ## Data Science  Capstone Project
#
# ### Week 2

# %% [markdown]
# # PART 1
# # INTRODUCTION TO BUSINESS UNDERSTANDING AND PROBLEM FRAMING
#
# All around the  world  roads are shared by cars, buses, trucks, motorcycles, pedestrians, animals, taxis, and other travelers. Travel made possible by motor vehicles supports economic and social development in most of  countries.
# Yet each year, vehicles are involved in accidents that are responsible for millions of deaths and injuries.
#
# Accordingly to the World Health Organization report " Global Status Report on Road Safety 2018", each year  1.35 million people are killed on roadways around the world. Every day, almost 3,700 people are killed globally in road traffic crashes involving cars, buses, motorcycles, bicycles, trucks, or pedestrians. More than 50% of those killed are pedestrians, motorcyclists, and cyclists.
#
# Despite measures and campaigns deployed by authorities the impact of accidents continues to be high an thus,it is of paramount importance to understand what are the factors that may serve as explanation to road accidents.
#
# If a model could be developed to understand what are the best predictors of the severity of an accident (ex, weather, trafic, road, visibility conditions etc) that would serve as a way to drive alerts that could help prevent accidents and mortality.

# %% [markdown]
# # PART 2
# # DATA UNDERSTANDING
# The data that has been made available for this project capstone was made available  by the Seattle Police Department, related with the Accident Traffic Records Department, collect from 2004 to present.  It consists of a data set that includes + 190 000 observations and 37 independent variables. The dependent variable, named  “SEVERITYCODE”, contains a numbered classification numbers  corresponding to different levels of severity caused by an accident from 0 to 3.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
# Loading of the dataset
df_data = pd.read_csv("/users/adelaide.leitao/downloads/Data-Collisions.csv")
# Out:
# C:\Users\adelaide.leitao\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_data.head()
# Out:
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY      ...      ROADCOND  \
# 0  Matched  Intersection  37475.0      ...           Wet
# 1  Matched         Block      NaN      ...           Wet
# 2  Matched         Block      NaN      ...           Dry
# 3  Matched         Block      NaN      ...           Dry
# 4  Matched  Intersection  34387.0      ...           Wet
#
#                  LIGHTCOND PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0                 Daylight           NaN         NaN      NaN         10
# ...

# %%
#understanding missing values 
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
# SEVERITYCODE      194673 non-null int64
# X                 189339 non-null float64
# Y                 189339 non-null float64
# OBJECTID          194673 non-null int64
# INCKEY            194673 non-null int64
# COLDETKEY         194673 non-null int64
# REPORTNO          194673 non-null object
# STATUS            194673 non-null object
# ADDRTYPE          192747 non-null object
# INTKEY            65070 non-null float64
# LOCATION          191996 non-null object
# EXCEPTRSNCODE     84811 non-null object
# EXCEPTRSNDESC     5638 non-null object
# SEVERITYCODE.1    194673 non-null int64
# SEVERITYDESC      194673 non-null object
# COLLISIONTYPE     189769 non-null object
# PERSONCOUNT       194673 non-null int64
# PEDCOUNT          194673 non-null int64
# PEDCYLCOUNT       194673 non-null int64
# VEHCOUNT          194673 non-null int64
# ...

# %% [markdown]
# The dataset is quite large. The target (dependent) variable is SEVERITY CODE ans I will consider different independent variables to identify the cause of road accidents and  level of severity.
# There is the need to make some filters, handle missing valus and decide if all columns are to be used or not; this will be made also by considering the metadata available.
